# %%
import pandas as pd
import numpy as np
from agent_based_model import *
# %load_ext autoreload
# %autoreload 2

# %%
infected_init_dic = {'H1N1': 10, 'H3N2': 0, 'B': 0}
alpha_dic = {'H1N1': 0.78, 'H3N2': 0.74, 'B': 0.6} # H1N1 was 0.78
lmbd = 0.2 # was 0.3
num_runs = 1
days = range(1, 2)
strains_keys = ['H1N1', 'H3N2', 'B']

# in data folder schould be 3 files: 'people.txt', 'households.txt', 'schools.json'
# TODO problem with saving files -- solve issue with path
#root = 'C:/'
#user = 'EGuseva/'
#files = 'crazy_lmbd/'
data_folder = 'sampled_200k/'
#data_path = root + user + files + 'data/' + data_folder
#results_dir = root + user + files + 'aresults/' + data_folder
#n='new_crazy_lmbd'
#es='results'
#data_path=f'C:/EGuseva/{n}/data/sampled_200k/'
#results_dir = f'C:/EGuseva/{n}/{es}/sampled_200k/'

data_path = 'sampled_200k/'
results_dir = 'samara_200k_res/'

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    print("Directory created successfully!")
else:
    print("Directory already exists!")
# sys.exit()

data, households, dict_school_id = load_data(data_path)
data, households, dict_school_id = preprocess_data(
    data, households, dict_school_id)
dict_school_len = [len(dict_school_id[i])
                   for i in dict_school_id.keys()]
data = set_initial_values(data, strains_keys, alpha_dic)
# Out:
# Directory already exists!

# %%
data
# Out:
#          sp_id  sp_hh_id  age sex work_id  susceptible_H1N1  susceptible_H3N2  \
# 179687  179688     30665   63   F   19887                 1                 1
# 105529  105530     46286   98   M   43279                 1                 1
# 144500  144501     36367   43   M   51440                 1                 1
# 69776    69777     34622   35   F   59813                 1                 0
# 189186  189187     29950   94   M   35880                 1                 1
# ...        ...       ...  ...  ..     ...               ...               ...
# 16736    16737     45363   27   F   28725                 1                 1
# 122167  122168     19461   59   F   23899                 1                 1
# 36720    36721     35722   73   M   16802                 1                 1
# 67246    67247     47457   64   F   55438                 1                 1
# 144623  144624     17298   54   M   44911                 1                 1
#
#         susceptible_B  infected  illness_day
# 179687              1         0            0
# 105529              1         0            0
# 144500              1         0            0
# 69776               1         0            0
# 189186              1         0            0
# ...               ...       ...          ...
# 16736               1         0            0
# 122167              1         0            0
# 36720               1         0            0
# 67246               1         0            0
# 144623              0         0            0
#
# [200000 rows x 10 columns]

# %%
results_dic, number_seed, lmbd, SEIRb_day, data_current = main_function(
                0, data_folder=data_folder, dataset=data,
              dict_school_id_all=dict_school_id, lmbd=lmbd, 
              infected_init_dic=infected_init_dic,
              days=days, dict_school_len=dict_school_len)
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  7.61it/s]
# All inf:  10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results_dic, number_seed, lmbd, SEIRb_day, data_current = main_function(
#       2                 0, data_folder=data_folder, dataset=data,
#       3               dict_school_id_all=dict_school_id, lmbd=lmbd,
#       4               infected_init_dic=infected_init_dic,
#       5               days=days, dict_school_len=dict_school_len)
#
# File ~\Documents\GitHub\ABM_gen\agent_based_model.py:470, in main_function(number_seed, data_folder, dataset, dict_school_id_all, lmbd, infected_init_dic, days, dict_school_len)
#     465     # ___________________________________________________
#     467     '''
#     468     штамм: сколько новых I, всего I, всего S
#     469     '''
# --> 470     print(f"day {j}, {key}: new I {newly_infected_by_strain} (all {c_inf}), all S {S_all}")
#     471     '''
#     472     print("{}: day {} {} I {}({}) S {} ".format(number_seed, j, key, newly_infected_by_strain, c_inf,
#     473           int(data_current[['susceptible_'+key]].sum()), datetime.datetime.now()))
#     474
#     475
#     476     '''
#     477 print()
#
# NameError: name 'S_all' is not defined
